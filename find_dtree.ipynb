# %%
import optuna
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import numpy as np
from training import *

# %%
features = ['macd', 'rsi', 'k', 'd', 'r', 'close',
            'before1day', 'before2day', 'before3day', 'before4day','before5day']
target = 'dailyreturn'
X_train, y_train = dataset_loading(features, target, './taiex_good_train_data.csv')
X_test, y_test = dataset_loading(features, target, './taiex_good_test_data.csv')
y_train = process_dataset(y_train, target)
y_test = process_dataset(y_test, target)

# %%
# Optuna 的目標函數：輸出交叉驗證分數（平均準確率）
def objective(trial):
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int('max_depth', 200, 300)
    min_samples_split = trial.suggest_int('min_samples_split', 20, 30)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 20, 30)

    clf = DecisionTreeClassifier(
        criterion=criterion,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )
    
    # 使用 5 折交叉驗證來評估模型表現
    score = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
    return score.mean()

# 建立並開始搜尋
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)  # 可自行調整搜尋次數

# 最佳結果
print("最佳參數組合：", study.best_params)
print("最佳交叉驗證分數：", study.best_value)

# 以最佳參數訓練最終模型並測試
best_clf = DecisionTreeClassifier(**study.best_params, random_state=42)
best_clf.fit(X_train, y_train)
y_pred = best_clf.predict(X_test)
print("測試集準確率：", accuracy_score(y_test, y_pred))
# Out:
# [I 2025-06-27 01:53:11,428] A new study created in memory with name: no-name-7eed6504-1736-43dd-8eb7-e995f90a71c5
# [I 2025-06-27 01:53:11,460] Trial 0 finished with value: 0.8389830508474576 and parameters: {'criterion': 'gini', 'max_depth': 257, 'min_samples_split': 27, 'min_samples_leaf': 27}. Best is trial 0 with value: 0.8389830508474576.
# [I 2025-06-27 01:53:11,501] Trial 1 finished with value: 0.8415254237288134 and parameters: {'criterion': 'entropy', 'max_depth': 203, 'min_samples_split': 22, 'min_samples_leaf': 30}. Best is trial 1 with value: 0.8415254237288134.
# [I 2025-06-27 01:53:11,540] Trial 2 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 259, 'min_samples_split': 26, 'min_samples_leaf': 21}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,571] Trial 3 finished with value: 0.8389830508474576 and parameters: {'criterion': 'gini', 'max_depth': 239, 'min_samples_split': 29, 'min_samples_leaf': 29}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,604] Trial 4 finished with value: 0.8398305084745763 and parameters: {'criterion': 'gini', 'max_depth': 226, 'min_samples_split': 26, 'min_samples_leaf': 26}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,642] Trial 5 finished with value: 0.8542372881355933 and parameters: {'criterion': 'entropy', 'max_depth': 221, 'min_samples_split': 25, 'min_samples_leaf': 22}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,673] Trial 6 finished with value: 0.8389830508474576 and parameters: {'criterion': 'gini', 'max_depth': 243, 'min_samples_split': 30, 'min_samples_leaf': 29}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,704] Trial 7 finished with value: 0.8406779661016948 and parameters: {'criterion': 'gini', 'max_depth': 276, 'min_samples_split': 29, 'min_samples_leaf': 24}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,735] Trial 8 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 271, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,772] Trial 9 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 298, 'min_samples_split': 24, 'min_samples_leaf': 26}. Best is trial 2 with value: 0.8567796610169491.
# [I 2025-06-27 01:53:11,819] Trial 10 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 289, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:11,863] Trial 11 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 293, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:11,905] Trial 12 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 298, 'min_samples_split': 20, 'min_samples_leaf': 23}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:11,947] Trial 13 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 285, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:11,990] Trial 14 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 285, 'min_samples_split': 22, 'min_samples_leaf': 23}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,033] Trial 15 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 271, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,076] Trial 16 finished with value: 0.8542372881355933 and parameters: {'criterion': 'entropy', 'max_depth': 288, 'min_samples_split': 21, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,118] Trial 17 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 300, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,160] Trial 18 finished with value: 0.8483050847457628 and parameters: {'criterion': 'entropy', 'max_depth': 260, 'min_samples_split': 20, 'min_samples_leaf': 24}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,203] Trial 19 finished with value: 0.8542372881355933 and parameters: {'criterion': 'entropy', 'max_depth': 280, 'min_samples_split': 22, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,245] Trial 20 finished with value: 0.8483050847457628 and parameters: {'criterion': 'entropy', 'max_depth': 290, 'min_samples_split': 24, 'min_samples_leaf': 24}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,288] Trial 21 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 289, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,330] Trial 22 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 268, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,373] Trial 23 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 283, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,417] Trial 24 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 291, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,460] Trial 25 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 277, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,502] Trial 26 finished with value: 0.8542372881355933 and parameters: {'criterion': 'entropy', 'max_depth': 295, 'min_samples_split': 20, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,545] Trial 27 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 267, 'min_samples_split': 22, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,588] Trial 28 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 276, 'min_samples_split': 21, 'min_samples_leaf': 23}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,625] Trial 29 finished with value: 0.8389830508474576 and parameters: {'criterion': 'gini', 'max_depth': 251, 'min_samples_split': 27, 'min_samples_leaf': 27}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,668] Trial 30 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 265, 'min_samples_split': 20, 'min_samples_leaf': 25}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,711] Trial 31 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 300, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,755] Trial 32 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 293, 'min_samples_split': 22, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,798] Trial 33 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 283, 'min_samples_split': 24, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,846] Trial 34 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 299, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,893] Trial 35 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 209, 'min_samples_split': 23, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,932] Trial 36 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 292, 'min_samples_split': 21, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:12,976] Trial 37 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 286, 'min_samples_split': 22, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,020] Trial 38 finished with value: 0.8415254237288134 and parameters: {'criterion': 'entropy', 'max_depth': 227, 'min_samples_split': 25, 'min_samples_leaf': 30}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,058] Trial 39 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 251, 'min_samples_split': 26, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,101] Trial 40 finished with value: 0.8457627118644068 and parameters: {'criterion': 'entropy', 'max_depth': 280, 'min_samples_split': 20, 'min_samples_leaf': 28}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,147] Trial 41 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 294, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,190] Trial 42 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 288, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,236] Trial 43 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 300, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,281] Trial 44 finished with value: 0.8542372881355933 and parameters: {'criterion': 'entropy', 'max_depth': 295, 'min_samples_split': 22, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,320] Trial 45 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 238, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,364] Trial 46 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 282, 'min_samples_split': 21, 'min_samples_leaf': 23}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,407] Trial 47 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 274, 'min_samples_split': 23, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,449] Trial 48 finished with value: 0.8542372881355933 and parameters: {'criterion': 'entropy', 'max_depth': 288, 'min_samples_split': 20, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,488] Trial 49 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 261, 'min_samples_split': 24, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,532] Trial 50 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 273, 'min_samples_split': 30, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,577] Trial 51 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 284, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,621] Trial 52 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 280, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,666] Trial 53 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 289, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,708] Trial 54 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 295, 'min_samples_split': 29, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,752] Trial 55 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 286, 'min_samples_split': 22, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,795] Trial 56 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 296, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,839] Trial 57 finished with value: 0.8542372881355933 and parameters: {'criterion': 'entropy', 'max_depth': 291, 'min_samples_split': 20, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,883] Trial 58 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 277, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,925] Trial 59 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 284, 'min_samples_split': 20, 'min_samples_leaf': 26}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:13,969] Trial 60 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 297, 'min_samples_split': 22, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,015] Trial 61 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 276, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,059] Trial 62 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 280, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,102] Trial 63 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 289, 'min_samples_split': 26, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,145] Trial 64 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 270, 'min_samples_split': 24, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,188] Trial 65 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 293, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,225] Trial 66 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 286, 'min_samples_split': 23, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,268] Trial 67 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 264, 'min_samples_split': 25, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,311] Trial 68 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 300, 'min_samples_split': 27, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,354] Trial 69 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 278, 'min_samples_split': 22, 'min_samples_leaf': 25}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,399] Trial 70 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 291, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,442] Trial 71 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 298, 'min_samples_split': 24, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,486] Trial 72 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 256, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,529] Trial 73 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 300, 'min_samples_split': 20, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,573] Trial 74 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 282, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,617] Trial 75 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 293, 'min_samples_split': 25, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,659] Trial 76 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 297, 'min_samples_split': 20, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,696] Trial 77 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 239, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,741] Trial 78 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 286, 'min_samples_split': 22, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,784] Trial 79 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 290, 'min_samples_split': 20, 'min_samples_leaf': 23}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,828] Trial 80 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 246, 'min_samples_split': 24, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,873] Trial 81 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 293, 'min_samples_split': 22, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,916] Trial 82 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 295, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:14,959] Trial 83 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 206, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,003] Trial 84 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 288, 'min_samples_split': 22, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,045] Trial 85 finished with value: 0.8432203389830508 and parameters: {'criterion': 'entropy', 'max_depth': 292, 'min_samples_split': 23, 'min_samples_leaf': 29}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,089] Trial 86 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 283, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,134] Trial 87 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 298, 'min_samples_split': 22, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,173] Trial 88 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 286, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,216] Trial 89 finished with value: 0.8432203389830508 and parameters: {'criterion': 'entropy', 'max_depth': 296, 'min_samples_split': 21, 'min_samples_leaf': 27}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,262] Trial 90 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 273, 'min_samples_split': 20, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,306] Trial 91 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 299, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,351] Trial 92 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 294, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,395] Trial 93 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 288, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,441] Trial 94 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 290, 'min_samples_split': 22, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,484] Trial 95 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 300, 'min_samples_split': 23, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,528] Trial 96 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 215, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,573] Trial 97 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 297, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,618] Trial 98 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 281, 'min_samples_split': 22, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,660] Trial 99 finished with value: 0.8483050847457628 and parameters: {'criterion': 'entropy', 'max_depth': 279, 'min_samples_split': 20, 'min_samples_leaf': 24}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,698] Trial 100 finished with value: 0.8474576271186441 and parameters: {'criterion': 'gini', 'max_depth': 291, 'min_samples_split': 21, 'min_samples_leaf': 22}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,742] Trial 101 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 294, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,786] Trial 102 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 285, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,830] Trial 103 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 294, 'min_samples_split': 20, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,874] Trial 104 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 288, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,918] Trial 105 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 296, 'min_samples_split': 21, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:15,962] Trial 106 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 298, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,006] Trial 107 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 292, 'min_samples_split': 21, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,051] Trial 108 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 228, 'min_samples_split': 24, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,095] Trial 109 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 283, 'min_samples_split': 22, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,138] Trial 110 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 290, 'min_samples_split': 20, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,182] Trial 111 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 287, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,225] Trial 112 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 284, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,269] Trial 113 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 300, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,312] Trial 114 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 295, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,357] Trial 115 finished with value: 0.8440677966101695 and parameters: {'criterion': 'entropy', 'max_depth': 292, 'min_samples_split': 21, 'min_samples_leaf': 26}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,401] Trial 116 finished with value: 0.8576271186440678 and parameters: {'criterion': 'entropy', 'max_depth': 289, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.8576271186440678.
# [I 2025-06-27 01:53:16,445] Trial 117 finished with value: 0.8567796610169491 and parameters: {'criterion': 'entropy', 'max_depth': 276, 'min_samples_split': 23, 'min_samples_leaf': 21}. Best is trial 10 with value: 0.8576271186440678.
# [W 2025-06-27 01:53:16,470] Trial 118 failed with parameters: {'criterion': 'entropy', 'max_depth': 298, 'min_samples_split': 21, 'min_samples_leaf': 20} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/yn/g32w0lns4mggyn92jf88495r0000gn/T/ipykernel_24448/2928866702.py", line 34, in objective
#     score = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 712, in cross_val_score
#     cv_results = cross_validate(
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 423, in cross_validate
#     results = parallel(
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 1009, in fit
#     super()._fit(
#   File "/Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 472, in _fit
#     builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
# KeyboardInterrupt
# [W 2025-06-27 01:53:16,474] Trial 118 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 39
#      37 # 建立並開始搜尋
#      38 study = optuna.create_study(direction='maximize')
# ---> 39 study.optimize(objective, n_trials=1000)  # 可自行調整搜尋次數
#      41 # 最佳結果
#      42 print("最佳參數組合：", study.best_params)
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/optuna/study/study.py:489, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     387 def optimize(
#     388     self,
#     389     func: ObjectiveFuncType,
#    (...)
#     396     show_progress_bar: bool = False,
#     397 ) -> None:
#     398     """Optimize an objective function.
#     399
#     400     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     487             If nested invocation of this method occurs.
#     488     """
# --> 489     _optimize(
#     490         study=self,
#     491         func=func,
#     492         n_trials=n_trials,
#     493         timeout=timeout,
#     494         n_jobs=n_jobs,
#     495         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     496         callbacks=callbacks,
#     497         gc_after_trial=gc_after_trial,
#     498         show_progress_bar=show_progress_bar,
#     499     )
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/optuna/study/_optimize.py:64, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      62 try:
#      63     if n_jobs == 1:
# ---> 64         _optimize_sequential(
#      65             study,
#      66             func,
#      67             n_trials,
#      68             timeout,
#      69             catch,
#      70             callbacks,
#      71             gc_after_trial,
#      72             reseed_sampler_rng=False,
#      73             time_start=None,
#      74             progress_bar=progress_bar,
#      75         )
#      76     else:
#      77         if n_jobs == -1:
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/optuna/study/_optimize.py:161, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158         break
#     160 try:
# --> 161     frozen_trial = _run_trial(study, func, catch)
#     162 finally:
#     163     # The following line mitigates memory problems that can be occurred in some
#     164     # environments (e.g., services that use computing containers such as GitHub Actions).
#     165     # Please refer to the following PR for further details:
#     166     # https://github.com/optuna/optuna/pull/325.
#     167     if gc_after_trial:
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/optuna/study/_optimize.py:253, in _run_trial(study, func, catch)
#     246         assert False, "Should not reach."
#     248 if (
#     249     frozen_trial.state == TrialState.FAIL
#     250     and func_err is not None
#     251     and not isinstance(func_err, catch)
#     252 ):
# --> 253     raise func_err
#     254 return frozen_trial
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[1], line 34, in objective(trial)
#      25 clf = DecisionTreeClassifier(
#      26     criterion=criterion,
#      27     max_depth=max_depth,
#    (...)
#      30     random_state=42
#      31 )
#      33 # 使用 5 折交叉驗證來評估模型表現
# ---> 34 score = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
#      35 return score.mean()
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:712, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     709 # To ensure multimetric format is not supported
#     710 scorer = check_scoring(estimator, scoring=scoring)
# --> 712 cv_results = cross_validate(
#     713     estimator=estimator,
#     714     X=X,
#     715     y=y,
#     716     groups=groups,
#     717     scoring={"score": scorer},
#     718     cv=cv,
#     719     n_jobs=n_jobs,
#     720     verbose=verbose,
#     721     fit_params=fit_params,
#     722     params=params,
#     723     pre_dispatch=pre_dispatch,
#     724     error_score=error_score,
#     725 )
#     726 return cv_results["test_score"]
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:423, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     420 # We clone the estimator to make sure that all the folds are
#     421 # independent, and that it is pickle-able.
#     422 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 423 results = parallel(
#     424     delayed(_fit_and_score)(
#     425         clone(estimator),
#     426         X,
#     427         y,
#     428         scorer=scorers,
#     429         train=train,
#     430         test=test,
#     431         verbose=verbose,
#     432         parameters=None,
#     433         fit_params=routed_params.estimator.fit,
#     434         score_params=routed_params.scorer.score,
#     435         return_train_score=return_train_score,
#     436         return_times=True,
#     437         return_estimator=return_estimator,
#     438         error_score=error_score,
#     439     )
#     440     for train, test in indices
#     441 )
#     443 _warn_or_raise_about_fit_failures(results, error_score)
#     445 # For callable scoring, the return type is only know after calling. If the
#     446 # return type is a dictionary, the error scores can now be inserted with
#     447 # the correct key.
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/tree/_classes.py:1009, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     978 @_fit_context(prefer_skip_nested_validation=True)
#     979 def fit(self, X, y, sample_weight=None, check_input=True):
#     980     """Build a decision tree classifier from the training set (X, y).
#     981
#     982     Parameters
#    (...)
#    1006         Fitted estimator.
#    1007     """
# -> 1009     super()._fit(
#    1010         X,
#    1011         y,
#    1012         sample_weight=sample_weight,
#    1013         check_input=check_input,
#    1014     )
#    1015     return self
#
# File /Applications/anaconda3/envs/brbm/lib/python3.9/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
dt_model = DecisionTreeClassifier(
    criterion = 'gini',
    max_depth = 7
    )
dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)
print("測試集準確率：", accuracy_score(y_test, y_pred))
features_len = len(np.where(dt_model.feature_importances_ > 0)[0])
features_len
# Out:
# 測試集準確率： 0.7878787878787878
# 10
